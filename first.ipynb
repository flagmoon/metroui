# %% [markdown]
# <a href="https://colab.research.google.com/github/flagmoon/metroui/blob/dev/first.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
